# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston

# %%
boston = load_boston()  # 보스턴 주택값 데이터

# %%
boston #bunch
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston.keys() #키값 확인, 컬럼명 보기
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston.DESCR
print(boston['DESCR']) #1978년 발표된 데이터로 보스턴 지역의 주택가격에 영향을 미치는 요인들을 정리함
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
pd.DataFrame(boston.data)
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston_df = pd.DataFrame(boston.data, columns = boston.feature_names)
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# CRIM 시별 1인당 범죄율
# ZN 25,000 평방피트를 초과하는 거주지역의 비율
# INDUS 비소매상업지역이 점유하고 있는 토지의 비율
# CHAS 찰스강에 대한 더미변수(있으면 1, 아니면 0)
# NOX 10ppm당 농축 일산화질소
# RM 주택 1가구당 평균 방의 개수
# AGE 1940년 이전 건축 주택의 비율
# DIS 5개의 보스턴 직업센터까지의 접근성 지수
# RAD 방사형 도로까지의 접근성 지수
# TAX 10,000달러 당 재산세율
# PTRATION 시별 학생/교사 비율
# B 시별 흑인의 비율
# LSTAT 하위계층의 비율
# MEDV 본인 소유 주택 가격(단위:$1,000)

# %%
house_price = boston.target
house_price
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %% [markdown]
# # train, test 분리

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Q1.
# - train_test_split 이용해서 train, test 분리
# - 순서는 X_train, X_test, y_train, y_test
# - 7:3 비율로 분리, random_state = 0

# %%
X_train, X_test, y_train, y_test = train_test_split(boston_df,house_price, 
                                                    test_size=0.3, random_state=0)

# %%
print(X_train)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 141  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394  4.0  437.0
# 272  0.11460  20.0   6.96   0.0  0.464  6.538   58.7  3.9175  3.0  223.0
# 135  0.55778   0.0  21.89   0.0  0.624  6.335   98.2  2.1107  4.0  437.0
# 298  0.06466  70.0   2.24   0.0  0.400  6.345   20.1  7.8278  5.0  358.0
# 122  0.09299   0.0  25.65   0.0  0.581  5.961   92.9  2.0869  2.0  188.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 323  0.28392   0.0   7.38   0.0  0.493  5.708   74.3  4.7211  5.0  287.0
# 192  0.08664  45.0   3.44   0.0  0.437  7.178   26.3  6.4798  5.0  398.0
# 117  0.15098   0.0  10.01   0.0  0.547  6.021   82.6  2.7474  6.0  432.0
# 47   0.22927   0.0   6.91   0.0  0.448  6.030   85.5  5.6894  3.0  233.0
# 172  0.13914   0.0   4.05   0.0  0.510  5.572   88.5  2.5961  5.0  296.0
#
#      PTRATIO       B  LSTAT
# 141     21.2  396.90  34.41
# 272     18.6  394.96   7.73
# ...

# %%
print(X_test)
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 329   0.06724  0.0   3.24   0.0  0.460  6.333   17.2  5.2146   4.0  430.0
# 371   9.23230  0.0  18.10   0.0  0.631  6.216  100.0  1.1691  24.0  666.0
# 219   0.11425  0.0  13.89   1.0  0.550  6.373   92.4  3.3633   5.0  276.0
# 403  24.80170  0.0  18.10   0.0  0.693  5.349   96.0  1.7028  24.0  666.0
# 78    0.05646  0.0  12.83   0.0  0.437  6.232   53.7  5.0141   5.0  398.0
# ..        ...  ...    ...   ...    ...    ...    ...     ...   ...    ...
# 4     0.06905  0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 428   7.36711  0.0  18.10   0.0  0.679  6.193   78.1  1.9356  24.0  666.0
# 385  16.81180  0.0  18.10   0.0  0.700  5.277   98.1  1.4261  24.0  666.0
# 308   0.49298  0.0   9.90   0.0  0.544  6.635   82.5  3.3175   4.0  304.0
# 5     0.02985  0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
#
#      PTRATIO       B  LSTAT
# 329     16.9  375.21   7.34
# ...

# %%
print(y_train)
# Out:
# [14.4 24.4 18.1 22.5 20.5 15.2 17.4 13.6  8.7 18.2 35.4 31.7 33.  22.2
#  20.4 23.9 25.  12.7 29.1 12.  17.7 27.  20.6 10.2 17.5 19.7 29.8 20.5
#  14.9 10.9 19.5 22.7 19.5 24.6 25.  24.5 50.  14.3 11.8 31.  28.7 16.2
#  43.5 25.  22.  19.9 22.1 46.  22.9 20.2 43.1 34.6 13.8 24.3 21.5 24.4
#  21.2 23.8 26.6 25.1  9.6 19.4 19.4  9.5 14.  26.5 13.8 34.7 16.3 21.7
#  17.5 15.6 20.9 21.7 12.7 18.5 23.7 19.3 12.7 21.6 23.2 29.6 21.2 23.8
#  17.1 22.  36.5 18.8 21.9 23.1 20.2 17.4 37.  24.1 36.2 15.7 32.2 13.5
#  17.9 13.3 11.7 41.7 18.4 13.1 25.  21.2 16.  34.9 25.2 24.8 21.5 23.4
#  18.9 10.8 21.  27.5 17.5 13.5 28.7 14.8 19.1 28.6 13.1 19.  11.3 13.3
#  22.4 20.1 18.2 22.9 20.6 25.  12.8 34.9 23.7 50.  29.  30.1 22.  15.6
#  23.3 30.1 14.3 22.8 50.  20.8  6.3 34.9 32.4 19.9 20.3 17.8 23.1 20.4
#  23.2  7.  16.8 46.7 50.  22.9 23.9 21.4 21.7 15.4 15.3 23.1 23.9 19.4
#  11.9 17.8 31.5 33.8 20.8 19.8 22.4  5.  24.5 19.4 15.1 18.2 19.3 27.1
# ...

# %%
print(y_test)
# Out:
# [22.6 50.  23.   8.3 21.2 19.9 20.6 18.7 16.1 18.6  8.8 17.2 14.9 10.5
#  50.  29.  23.  33.3 29.4 21.  23.8 19.1 20.4 29.1 19.3 23.1 19.6 19.4
#  38.7 18.7 14.6 20.  20.5 20.1 23.6 16.8  5.6 50.  14.5 13.3 23.9 20.
#  19.8 13.8 16.5 21.6 20.3 17.  11.8 27.5 15.6 23.1 24.3 42.8 15.6 21.7
#  17.1 17.2 15.  21.7 18.6 21.  33.1 31.5 20.1 29.8 15.2 15.  27.5 22.6
#  20.  21.4 23.5 31.2 23.7  7.4 48.3 24.4 22.6 18.3 23.3 17.1 27.9 44.8
#  50.  23.  21.4 10.2 23.3 23.2 18.9 13.4 21.9 24.8 11.9 24.3 13.8 24.7
#  14.1 18.7 28.1 19.8 26.7 21.7 22.  22.9 10.4 21.9 20.6 26.4 41.3 17.2
#  27.1 20.4 16.5 24.4  8.4 23.   9.7 50.  30.5 12.3 19.4 21.2 20.3 18.8
#  33.4 18.5 19.6 33.2 13.1  7.5 13.6 17.4  8.4 35.4 24.  13.4 26.2  7.2
#  13.1 24.5 37.2 25.  24.1 16.6 32.9 36.2 11.   7.2 22.8 28.7]

# %%
# corr 상관관계 확인
boston_copy = X_train.copy()
boston_copy['PRICE'] = y_train
boston_copy.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 141  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394  4.0  437.0
# 272  0.11460  20.0   6.96   0.0  0.464  6.538   58.7  3.9175  3.0  223.0
# 135  0.55778   0.0  21.89   0.0  0.624  6.335   98.2  2.1107  4.0  437.0
# 298  0.06466  70.0   2.24   0.0  0.400  6.345   20.1  7.8278  5.0  358.0
# 122  0.09299   0.0  25.65   0.0  0.581  5.961   92.9  2.0869  2.0  188.0
#
#      PTRATIO       B  LSTAT  PRICE
# 141     21.2  396.90  34.41   14.4
# 272     18.6  394.96   7.73   24.4
# 135     21.2  394.67  16.96   18.1
# 298     14.8  368.24   4.97   22.5
# 122     19.1  378.09  17.93   20.5

# %%
print(id(X_train))
print(id(boston_copy))
# Out:
# 2516146521352
# 2516146654536

# %%
# corr 상관관계 확인
boston_copy = X_train.copy()
boston_copy['PRICE'] = y_train
boston_copy.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 141  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394  4.0  437.0
# 272  0.11460  20.0   6.96   0.0  0.464  6.538   58.7  3.9175  3.0  223.0
# 135  0.55778   0.0  21.89   0.0  0.624  6.335   98.2  2.1107  4.0  437.0
# 298  0.06466  70.0   2.24   0.0  0.400  6.345   20.1  7.8278  5.0  358.0
# 122  0.09299   0.0  25.65   0.0  0.581  5.961   92.9  2.0869  2.0  188.0
#
#      PTRATIO       B  LSTAT  PRICE
# 141     21.2  396.90  34.41   14.4
# 272     18.6  394.96   7.73   24.4
# 135     21.2  394.67  16.96   18.1
# 298     14.8  368.24   4.97   22.5
# 122     19.1  378.09  17.93   20.5

# %%
boston_copy.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.196172  0.382073 -0.049364  0.416560 -0.188280  0.329927
# ZN      -0.196172  1.000000 -0.529392 -0.063863 -0.523572  0.319260 -0.583885
# INDUS    0.382073 -0.529392  1.000000  0.044224  0.750218 -0.392969  0.629257
# CHAS    -0.049364 -0.063863  0.044224  1.000000  0.043748  0.088125  0.067269
# NOX      0.416560 -0.523572  0.750218  0.043748  1.000000 -0.279202  0.740052
# RM      -0.188280  0.319260 -0.392969  0.088125 -0.279202  1.000000 -0.235839
# AGE      0.329927 -0.583885  0.629257  0.067269  0.740052 -0.235839  1.000000
# DIS     -0.355840  0.658331 -0.686848 -0.085492 -0.765753  0.183857 -0.761543
# RAD      0.603880 -0.314833  0.578459  0.022338  0.627188 -0.179242  0.440578
# TAX      0.560570 -0.327834  0.719038 -0.017156  0.683445 -0.275242  0.502429
# PTRATIO  0.264780 -0.392838  0.388353 -0.072683  0.179046 -0.385526  0.239729
# ...

# %%
boston_copy.corr().abs() #절대값
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000  0.196172  0.382073  0.049364  0.416560  0.188280  0.329927
# ZN       0.196172  1.000000  0.529392  0.063863  0.523572  0.319260  0.583885
# INDUS    0.382073  0.529392  1.000000  0.044224  0.750218  0.392969  0.629257
# CHAS     0.049364  0.063863  0.044224  1.000000  0.043748  0.088125  0.067269
# NOX      0.416560  0.523572  0.750218  0.043748  1.000000  0.279202  0.740052
# RM       0.188280  0.319260  0.392969  0.088125  0.279202  1.000000  0.235839
# AGE      0.329927  0.583885  0.629257  0.067269  0.740052  0.235839  1.000000
# DIS      0.355840  0.658331  0.686848  0.085492  0.765753  0.183857  0.761543
# RAD      0.603880  0.314833  0.578459  0.022338  0.627188  0.179242  0.440578
# TAX      0.560570  0.327834  0.719038  0.017156  0.683445  0.275242  0.502429
# PTRATIO  0.264780  0.392838  0.388353  0.072683  0.179046  0.385526  0.239729
# ...

# %%
boston_cor = boston_copy.corr().abs()
boston_cor .sort_values(by='PRICE', ascending = False)
#LSTAT 상관 관계가 높음 - 하위계층 비율
#RM 두번째로 높음 - 방의갯수
#PTRATIO 세번째로 높음 - 학생/교사
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# PRICE    0.388182  0.386115  0.504361  0.162395  0.426690  0.708978  0.390942
# LSTAT    0.439369  0.429178  0.603374  0.059060  0.577154  0.623920  0.606530
# RM       0.188280  0.319260  0.392969  0.088125  0.279202  1.000000  0.235839
# PTRATIO  0.264780  0.392838  0.388353  0.072683  0.179046  0.385526  0.239729
# INDUS    0.382073  0.529392  1.000000  0.044224  0.750218  0.392969  0.629257
# TAX      0.560570  0.327834  0.719038  0.017156  0.683445  0.275242  0.502429
# NOX      0.416560  0.523572  0.750218  0.043748  1.000000  0.279202  0.740052
# AGE      0.329927  0.583885  0.629257  0.067269  0.740052  0.235839  1.000000
# RAD      0.603880  0.314833  0.578459  0.022338  0.627188  0.179242  0.440578
# CRIM     1.000000  0.196172  0.382073  0.049364  0.416560  0.188280  0.329927
# ZN       0.196172  1.000000  0.529392  0.063863  0.523572  0.319260  0.583885
# ...

# %% [markdown]
# ### LinearRegression 선형회귀 모델

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linear_model.score(X_train,y_train)
# Out:
# 0.7645451026942549

# %%
linear_model.score(X_test,y_test)
# Out:
# 0.6733825506400194

# %%
result = cross_val_score(linear_model,
                        X_train,
                        y_train,
                        cv=5)
result
# Out:
# array([0.7246982 , 0.58082515, 0.77515092, 0.72161474, 0.78935797])

# %%
result.mean()
# Out:
# 0.718329397431593

# %% [markdown]
# ### 현재 선형모델은 Train모델에 대해서 정확도가 높게 나타난다.
# #### 모델 성능을 개선해야함

# %%
# 특성을 늘려보자
X_train['LSTAT']
# Out:
# 141    34.41
# 272     7.73
# 135    16.96
# 298     4.97
# 122    17.93
#        ...
# 323    11.74
# 192     2.87
# 117    10.30
# 47     18.80
# 172    14.69
# Name: LSTAT, Length: 354, dtype: float64

# %%
#LSTAT 하위계층 비율
plt.scatter(X_train['LSTAT'], y_train)

# %%
model = LinearRegression()
model.fit(X_train[['LSTAT']], y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pre = model.predict(X_train[['LSTAT']])
pre
# Out:
# array([ 1.47605623, 27.30605233, 18.3701129 , 29.9781209 , 17.43101634,
#        16.66618512, 22.11681773, 14.43946132,  9.18245687, 24.85665615,
#        30.34601439, 29.70704148, 26.99624728, 22.40725997, 27.33509656,
#        27.79980413, 27.24796389, 18.96067878, 30.54932396, 10.67339367,
#        20.60651811, 29.46500628, 21.87478254, 13.70367433, 20.17085476,
#        14.32328443, 23.50125906, 25.660213  , 19.07685567, 20.73237641,
#        25.30200091, 23.52062187, 16.72427357, 29.87162541, 25.59244315,
#        28.9906173 , 30.4815541 , 19.08653708, 11.5737646 , 23.89819678,
#        29.27137812, 23.65616158, 31.73045571, 28.77762633, 25.59244315,
#        21.10995132, 29.00029871, 31.87567683, 26.8897518 , 23.47221483,
#        27.7610785 , 28.3806886 ,  7.87546681, 28.56463535, 21.13899554,
#        29.07774997, 24.5468511 , 23.03655148, 28.46782127, 25.55371752,
#        17.31483945, 24.87601897, 23.44317061, 11.47695052, 11.39949926,
# ...

# %%
# 시각화
plt.scatter(X_train['LSTAT'],y_train)
plt.scatter(X_train['LSTAT'], pre)

# %%
# 'LSTAT X LSTAT' 특성 확장
X_train['LSTAT X LSTAT'] = X_train['LSTAT'] * X_train['LSTAT']

model2 = LinearRegression()
model2.fit(X_train[['LSTAT','LSTAT X LSTAT']], y_train)
pre2 = model2.predict(X_train[['LSTAT','LSTAT X LSTAT']])
plt.scatter(X_train['LSTAT'],y_train)
plt.scatter(X_train['LSTAT'],pre2)
# Out:
# C:\Users\SMT047\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X_test['LSTAT x LSTAT'] = X_test['LSTAT'] * X_test['LSTAT']
# Out:
# C:\Users\SMT047\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 329   0.06724  0.0   3.24   0.0  0.460  6.333   17.2  5.2146   4.0  430.0
# 371   9.23230  0.0  18.10   0.0  0.631  6.216  100.0  1.1691  24.0  666.0
# 219   0.11425  0.0  13.89   1.0  0.550  6.373   92.4  3.3633   5.0  276.0
# 403  24.80170  0.0  18.10   0.0  0.693  5.349   96.0  1.7028  24.0  666.0
# 78    0.05646  0.0  12.83   0.0  0.437  6.232   53.7  5.0141   5.0  398.0
# ..        ...  ...    ...   ...    ...    ...    ...     ...   ...    ...
# 4     0.06905  0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 428   7.36711  0.0  18.10   0.0  0.679  6.193   78.1  1.9356  24.0  666.0
# 385  16.81180  0.0  18.10   0.0  0.700  5.277   98.1  1.4261  24.0  666.0
# 308   0.49298  0.0   9.90   0.0  0.544  6.635   82.5  3.3175   4.0  304.0
# 5     0.02985  0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
#
#      PTRATIO       B  LSTAT  LSTAT x LSTAT
# ...

# %%
linear_model = LinearRegression()
linear_model.fit(X_train,y_train)
linear_model.score(X_test,y_test) # R square
# Out:
# 0.6978697736472479

# %%
X_train['RM X RM'] = X_train['RM'] * X_train['RM']
X_test['RM x RM'] = X_test['RM'] * X_test['RM']
# Out:
# C:\Users\SMT047\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SMT047\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 'RM' 특성 확장
model3 = LinearRegression()
model3.fit(X_train[['RM','RM X RM']],y_train)
pre3 = model3.predict(X_train[['RM','RM X RM']])
pre3
# 시각화 (이 예측이 실제 그래프랑 얼마나 차이나는지 그래프로 알아보자)
plt.scatter(X_train['RM'],y_train)
plt.scatter(X_train['RM'],pre3)

# %%
X_train['PTRATIO X PTRATIO'] = X_train['PTRATIO'] * X_train['PTRATIO']
X_test['PTRATIO x PTRATIO'] = X_test['PTRATIO'] * X_test['PTRATIO']
# Out:
# C:\Users\SMT047\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SMT047\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 'PTRATIO' 특성 확장
model4 = LinearRegression()
model4.fit(X_train[['PTRATIO', 'PTRATIO X PTRATIO']],y_train)
pre4 = model4.predict(X_train[['PTRATIO', 'PTRATIO X PTRATIO']])
pre4
# 시각화 (이 예측이 실제 그래프랑 얼마나 차이나는지 그래프로 알아보자)
plt.scatter(X_train['PTRATIO'],y_train)
plt.scatter(X_train['PTRATIO'],pre4)

# %% [markdown]
# ### 특성확장

# %%
# 원본 데이터 훼손 안하려고 카피를 한다.
extended_X_train = X_train.copy()
extended_X_train
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 141  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394  4.0  437.0
# 272  0.11460  20.0   6.96   0.0  0.464  6.538   58.7  3.9175  3.0  223.0
# 135  0.55778   0.0  21.89   0.0  0.624  6.335   98.2  2.1107  4.0  437.0
# 298  0.06466  70.0   2.24   0.0  0.400  6.345   20.1  7.8278  5.0  358.0
# 122  0.09299   0.0  25.65   0.0  0.581  5.961   92.9  2.0869  2.0  188.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 323  0.28392   0.0   7.38   0.0  0.493  5.708   74.3  4.7211  5.0  287.0
# 192  0.08664  45.0   3.44   0.0  0.437  7.178   26.3  6.4798  5.0  398.0
# 117  0.15098   0.0  10.01   0.0  0.547  6.021   82.6  2.7474  6.0  432.0
# 47   0.22927   0.0   6.91   0.0  0.448  6.030   85.5  5.6894  3.0  233.0
# 172  0.13914   0.0   4.05   0.0  0.510  5.572   88.5  2.5961  5.0  296.0
#
#      PTRATIO       B  LSTAT  LSTAT X LSTAT    RM X RM  PTRATIO X PTRATIO
# ...

# %%
for col1 in X_train.columns:
    for col2 in X_train.columns:
        extended_X_train[col1 + 'X' + col2] = X_train[col1] * X_train[col2]

# %%
extended_X_train.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  ...  \
# 141  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394  4.0  437.0  ...
# 272  0.11460  20.0   6.96   0.0  0.464  6.538   58.7  3.9175  3.0  223.0  ...
# 135  0.55778   0.0  21.89   0.0  0.624  6.335   98.2  2.1107  4.0  437.0  ...
# 298  0.06466  70.0   2.24   0.0  0.400  6.345   20.1  7.8278  5.0  358.0  ...
# 122  0.09299   0.0  25.65   0.0  0.581  5.961   92.9  2.0869  2.0  188.0  ...
#
#      PTRATIO X PTRATIOXAGE  PTRATIO X PTRATIOXDIS  PTRATIO X PTRATIOXRAD  \
# 141              44944.000             646.923936                1797.76
# 272              20307.852            1355.298300                1037.88
# 135              44135.008             948.633008                1797.76
# 298               4402.704            1714.601312                1095.20
# 122              33890.849             761.321989                 729.62
#
# ...

# %%
linear_model = LinearRegression()
linear_model.fit(extended_X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linear_model.score(extended_X_train, y_train)
# Out:
# 0.9737938367573458

# %%
#extended_X_test도 특성확장 해주세요
extended_X_test = X_test.copy()

extended_X_test

for col1 in X_test.columns:
    for col2 in X_test.columns:
        extended_X_test[col1 + 'X' + col2] = X_test[col1] * X_test[col2]
        
linear_model = LinearRegression()
linear_model.fit(extended_X_train, y_train)

linear_model.score(extended_X_test,y_test)
# Out:
# 0.5254083791717068

# %% [markdown]
# #### Ridge

# %%
# 과대적합을 풀어주자
from sklearn.linear_model import Ridge

# %%
#규제를 해준다 = 특성의 가중치가 낮아진다. 과대 적합을 풀어준다.
ridge_model = Ridge(alpha = 100) #0.01 0.1 10 100 1000 10000

# %%
ridge_model.fit(extended_X_train, y_train)
# Out:
# Ridge(alpha=100, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
#나는 왜 떨어졌을까 alpha값이 1일때
ridge_model.score(extended_X_test, y_test)
# Out:
# 0.7230665732759987

# %%
# 알파 하이퍼 파라미터를 조정해줬더니 과대적합이 어느정도 해소되었다.
